# %%
import pandas as pd

df_golpes = pd.read_parquet("../data/processed/golpes.parquet")
df_golpes.loc[:, ["clip_start", "marcador", "golpe_q"]].head(100)

# %%
df_golpes.to_excel("../data/processed/golpes.xlsx", index=False)

# %%
df = pd.read_parquet("../data/processed/golpes.parquet")
df[["set_p1","set_p2","juego_p1","juego_p2","punto_p1","punto_p2"]].head(30)

# %%
df_golpes[["inicio_x", "inicio_y", "fin_x", "fin_y"]].head(50)

# %%
df_golpes
